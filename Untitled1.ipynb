# %% [markdown]
# <a href="https://colab.research.google.com/github/lukayan15/lukayan/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Prit("I Competição de Programação Da Start ")
# Out:
# I Competição de Programação Da Start

# %%
ano = "II"

print(ano, "Competição de Programação da start")
# Out:
#   File "/tmp/ipython-input-2995216839.py", line 3
#     print(ano, Competição de Programação da start)
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
Print(f"")
