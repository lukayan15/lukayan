# %% [markdown]
# <a href="https://colab.research.google.com/github/lukayan15/lukayan/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## aula 1

# %%
print ("I Competição de Programação da Start")
# Out:
# I competição de programação da start

# %%
ano = "II"

print(ano,"Competição de Programação da Start")
# Out:
# II competição de programação da start

# %%
print(f"{ano} Competição de Programação da Start")
# Out:
# II competição de programação da start

# %% [markdown]
# aula 2
